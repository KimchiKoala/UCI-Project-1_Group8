# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import Dependencies
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas as pd

# %%
# Store filepath in a variable 2015
states2015_df = pd.read_excel('Murder2015.xlsx')
states2015_df.head()
# Out:
#         State  Total_murders  Total_firearms  Hand_guns  Rifles  Shotguns  \
# 0     Alabama              3               3          1       0         1
# 1      Alaska             57              39         12       2         1
# 2     Arizona            278             171        128       4         3
# 3    Arkansas            164             110         51      10         4
# 4  California           1861            1275        855      34        33
#
#    Firearms(typeunknown)  Knives orcuttinginstruments  Other_weapons  \
# 0                      1                            0              0
# 1                     24                            7              8
# 2                     36                           42             55
# 3                     45                           18             30
# 4                    353                          263            233
#
#    Hands_fists
# 0            0
# 1            3
# 2           10
# 3            6
# 4           90

# %%
#Rename columns 2015
states2015_df.rename(columns = {"Total_murders": "Total_murders2015", "Total_firearms": "Total_firearms2015"}, inplace = True)

states2015_df.head()
# Out:
#         State  Total_murders2015  Total_firearms2015  Hand_guns  Rifles  \
# 0     Alabama                  3                   3          1       0
# 1      Alaska                 57                  39         12       2
# 2     Arizona                278                 171        128       4
# 3    Arkansas                164                 110         51      10
# 4  California               1861                1275        855      34
#
#    Shotguns  Firearms(typeunknown)  Knives orcuttinginstruments  \
# 0         1                      1                            0
# 1         1                     24                            7
# 2         3                     36                           42
# 3         4                     45                           18
# 4        33                    353                          263
#
#    Other_weapons  Hands_fists
# 0              0            0
# 1              8            3
# 2             55           10
# 3             30            6
# 4            233           90

# %%
# sift columns 2015

data2015 = states2015_df [["State", "Total_murders2015", "Total_firearms2015"]]

data2015.head()
# Out:
#         State  Total_murders2015  Total_firearms2015
# 0     Alabama                  3                   3
# 1      Alaska                 57                  39
# 2     Arizona                278                 171
# 3    Arkansas                164                 110
# 4  California               1861                1275

# %%
# Store filepath in a variable 2016
states2016_df = pd.read_excel('Murder2016.xlsx')
states2016_df.head()
# Out:
#         State  Total_murders  Total_firearms  Hand_guns  Rifles  Shotguns  \
# 0     Alabama              3               1          0       0         0
# 1      Alaska             52              43         12       4         1
# 2     Arizona            336             227        156      16        10
# 3    Arkansas            209             151         72      11         3
# 4  California           1930            1368        930      37        36
#
#    Firearms(typeunknown)  Knives orcuttinginstruments  Other_weapons  \
# 0                      1                            0              2
# 1                     26                            3              6
# 2                     45                           40             63
# 3                     65                           25             25
# 4                    365                          280            193
#
#    Hands_fists
# 0            0
# 1            0
# 2            6
# 3            8
# 4           89

# %%
#Rename columns 2016
states2016_df.rename(columns = {"Total_murders": "Total_murders2016", "Total_firearms": "Total_firearms2016"}, inplace = True)

states2016_df.head()
# Out:
#         State  Total_murders2016  Total_firearms2016  Hand_guns  Rifles  \
# 0     Alabama                  3                   1          0       0
# 1      Alaska                 52                  43         12       4
# 2     Arizona                336                 227        156      16
# 3    Arkansas                209                 151         72      11
# 4  California               1930                1368        930      37
#
#    Shotguns  Firearms(typeunknown)  Knives orcuttinginstruments  \
# 0         0                      1                            0
# 1         1                     26                            3
# 2        10                     45                           40
# 3         3                     65                           25
# 4        36                    365                          280
#
#    Other_weapons  Hands_fists
# 0              2            0
# 1              6            0
# 2             63            6
# 3             25            8
# 4            193           89

# %%
# sift columns 2016

data2016 = states2016_df [["State", "Total_murders2016", "Total_firearms2016"]]

data2016.head()
# Out:
#         State  Total_murders2016  Total_firearms2016
# 0     Alabama                  3                   1
# 1      Alaska                 52                  43
# 2     Arizona                336                 227
# 3    Arkansas                209                 151
# 4  California               1930                1368

# %%
#Combine dataset into a single dataset 2015 2016

obama_merge_df = pd.merge(data2015, data2016, on="State")

#Display datatable for preview

obama_merge_df.head()
# Out:
#         State  Total_murders2015  Total_firearms2015  Total_murders2016  \
# 0     Alabama                  3                   3                  3
# 1      Alaska                 57                  39                 52
# 2     Arizona                278                 171                336
# 3    Arkansas                164                 110                209
# 4  California               1861                1275               1930
#
#    Total_firearms2016
# 0                   1
# 1                  43
# 2                 227
# 3                 151
# 4                1368

# %%
# calculate obama total murders for years 2015 and 2016

Obama_total_murders_15_16 = ((obama_merge_df["Total_murders2015"] + obama_merge_df["Total_murders2016"])/2).round().astype(int)
Obama_total_murders_15_16.head()
# Out:
# 0       3
# 1      54
# 2     307
# 3     186
# 4    1896
# dtype: int32

# %%
# calculate obama total firearms for years 2015 and 2016


Obama_total_firearms_15_16 = ((obama_merge_df["Total_firearms2015"] + obama_merge_df["Total_firearms2016"])/2).round().astype(int)
Obama_total_firearms_15_16.head()
# Out:
# 0       2
# 1      41
# 2     199
# 3     130
# 4    1322
# dtype: int32

# %%
obama_merge_df["obama_murder_mean"]=Obama_total_murders_15_16

# %%
obama_merge_df.head()
# Out:
#         State  Total_murders2015  Total_firearms2015  Total_murders2016  \
# 0     Alabama                  3                   3                  3
# 1      Alaska                 57                  39                 52
# 2     Arizona                278                 171                336
# 3    Arkansas                164                 110                209
# 4  California               1861                1275               1930
#
#    Total_firearms2016  obama_murder_mean
# 0                   1                  3
# 1                  43                 54
# 2                 227                307
# 3                 151                186
# 4                1368               1896

# %%
obama_merge_df["obama_firearms_mean"]=Obama_total_firearms_15_16

# %%
obama_merge_df.head()
# Out:
#         State  Total_murders2015  Total_firearms2015  Total_murders2016  \
# 0     Alabama                  3                   3                  3
# 1      Alaska                 57                  39                 52
# 2     Arizona                278                 171                336
# 3    Arkansas                164                 110                209
# 4  California               1861                1275               1930
#
#    Total_firearms2016  obama_murder_mean  obama_firearms_mean
# 0                   1                  3                    2
# 1                  43                 54                   41
# 2                 227                307                  199
# 3                 151                186                  130
# 4                1368               1896                 1322

# %%
obama1 = obama_merge_df.groupby("State").count()["obama_murder_mean"]
total_murder_bar = pd.DataFrame(obama1)

regbar = total_murder_bar.plot.bar(legend=False,rot=80)
plt.title("Total Number of Murders by State")
plt.xlabel("State")
plt.ylabel("obama_murder_mean")
# Out:
# Text(0, 0.5, 'obama_murder_mean')

# %%
obama2 = obama_merge_df.groupby("State").count()["obama_firearms_mean"]
total_firearms_bar = pd.DataFrame(obama2)

regbar = total_firearms_bar.plot.bar(legend=False,rot=80)
plt.title("Total Number of firearms by State")
plt.xlabel("State")
plt.ylabel("obama_firearms_mean")
# Out:
# Text(0, 0.5, 'obama_firearms_mean')

# %%
# Store filepath in a variable 2017
states2017_df = pd.read_excel('Murder2017.xlsx')
states2017_df.head()
# Out:
#         State  Total_murders  Total_firearms  Hand_guns  Rifles  Shotguns  \
# 0     Alabama              2               1          0       0         0
# 1      Alaska             62              37          7       3         3
# 2     Arizona            404             249        162       8         9
# 3    Arkansas            250             168         92      11         4
# 4  California           1830            1274        886      37        34
#
#    Firearms(typeunknown)  Knives orcuttinginstruments  Other_weapons  \
# 0                      1                            0              1
# 1                     24                           13              8
# 2                     70                           50             93
# 3                     61                           23             52
# 4                    317                          258            195
#
#    Hands_fists
# 0            0
# 1            4
# 2           12
# 3            7
# 4          103

# %%
#Rename columns 2017
states2017_df.rename(columns = {"Total_murders": "Total_murders2017", "Total_firearms": "Total_firearms2017"}, inplace = True)

states2017_df.head()
# Out:
#         State  Total_murders2017  Total_firearms2017  Hand_guns  Rifles  \
# 0     Alabama                  2                   1          0       0
# 1      Alaska                 62                  37          7       3
# 2     Arizona                404                 249        162       8
# 3    Arkansas                250                 168         92      11
# 4  California               1830                1274        886      37
#
#    Shotguns  Firearms(typeunknown)  Knives orcuttinginstruments  \
# 0         0                      1                            0
# 1         3                     24                           13
# 2         9                     70                           50
# 3         4                     61                           23
# 4        34                    317                          258
#
#    Other_weapons  Hands_fists
# 0              1            0
# 1              8            4
# 2             93           12
# 3             52            7
# 4            195          103

# %%
# sift columns 2017

data2017 = states2017_df [["State", "Total_murders2017", "Total_firearms2017"]]

data2017.head()
# Out:
#         State  Total_murders2017  Total_firearms2017
# 0     Alabama                  2                   1
# 1      Alaska                 62                  37
# 2     Arizona                404                 249
# 3    Arkansas                250                 168
# 4  California               1830                1274

# %%
# Store filepath in a variable 2018
states2018_df = pd.read_excel('Murder2018.xlsx')
states2018_df.head()
# Out:
#         State  Total_murders  Total_firearms  Hand_guns  Rifles  Shotguns  \
# 0     Alabama              2               2          2       0         0
# 1      Alaska             47              31          7       3         0
# 2     Arizona            339             203        139      12         6
# 3    Arkansas            218             156         66       6         5
# 4  California           1739            1177        834      24        27
#
#    Firearms(typeunknown)  Knives orcuttinginstruments  Other_weapons  \
# 0                      0                            0              0
# 1                     21                            8              3
# 2                     46                           45             87
# 3                     79                           17             38
# 4                    292                          252            223
#
#    Hands_fists
# 0            0
# 1            5
# 2            4
# 3            7
# 4           87

# %%
#Rename columns 2018
states2018_df.rename(columns = {"Total_murders": "Total_murders2018", "Total_firearms": "Total_firearms2018"}, inplace = True)

states2018_df.head()
# Out:
#         State  Total_murders2018  Total_firearms2018  Hand_guns  Rifles  \
# 0     Alabama                  2                   2          2       0
# 1      Alaska                 47                  31          7       3
# 2     Arizona                339                 203        139      12
# 3    Arkansas                218                 156         66       6
# 4  California               1739                1177        834      24
#
#    Shotguns  Firearms(typeunknown)  Knives orcuttinginstruments  \
# 0         0                      0                            0
# 1         0                     21                            8
# 2         6                     46                           45
# 3         5                     79                           17
# 4        27                    292                          252
#
#    Other_weapons  Hands_fists
# 0              0            0
# 1              3            5
# 2             87            4
# 3             38            7
# 4            223           87

# %%
# sift columns 2018

data2018 = states2018_df [["State", "Total_murders2018", "Total_firearms2018"]]

data2018.head()
# Out:
#         State  Total_murders2018  Total_firearms2018
# 0     Alabama                  2                   2
# 1      Alaska                 47                  31
# 2     Arizona                339                 203
# 3    Arkansas                218                 156
# 4  California               1739                1177

# %%
#Combine dataset into a single dataset 2017 2018

trump_merge_df = pd.merge(data2017, data2018, on="State")

#Display datatable for preview

trump_merge_df.head()
# Out:
#         State  Total_murders2017  Total_firearms2017  Total_murders2018  \
# 0     Alabama                  2                   1                  2
# 1      Alaska                 62                  37                 47
# 2     Arizona                404                 249                339
# 3    Arkansas                250                 168                218
# 4  California               1830                1274               1739
#
#    Total_firearms2018
# 0                   2
# 1                  31
# 2                 203
# 3                 156
# 4                1177

# %%
# calculate trump total murders for years 2017 and 2018

trump_total_murders_17_18 = ((trump_merge_df["Total_murders2017"] + trump_merge_df["Total_murders2018"])/2).round().astype(int)
trump_total_murders_17_18.head()
# Out:
# 0       2
# 1      54
# 2     372
# 3     234
# 4    1784
# dtype: int32

# %%
# calculate trump total firearms for years 2017 and 2018

trump_total_firearms_17_18 = ((trump_merge_df["Total_firearms2017"] + trump_merge_df["Total_firearms2018"])/2).round().astype(int)
trump_total_firearms_17_18.head()
# Out:
# 0       2
# 1      34
# 2     226
# 3     162
# 4    1226
# dtype: int32

# %%
trump_merge_df["trump_murder_mean"]=trump_total_murders_17_18

# %%
trump_merge_df.head()
# Out:
#         State  Total_murders2017  Total_firearms2017  Total_murders2018  \
# 0     Alabama                  2                   1                  2
# 1      Alaska                 62                  37                 47
# 2     Arizona                404                 249                339
# 3    Arkansas                250                 168                218
# 4  California               1830                1274               1739
#
#    Total_firearms2018  trump_murder_mean
# 0                   2                  2
# 1                  31                 54
# 2                 203                372
# 3                 156                234
# 4                1177               1784

# %%
trump_merge_df["trump_firearms_mean"]=trump_total_firearms_17_18

# %%
trump_merge_df.head()
# Out:
#         State  Total_murders2017  Total_firearms2017  Total_murders2018  \
# 0     Alabama                  2                   1                  2
# 1      Alaska                 62                  37                 47
# 2     Arizona                404                 249                339
# 3    Arkansas                250                 168                218
# 4  California               1830                1274               1739
#
#    Total_firearms2018  trump_murder_mean  trump_firearms_mean
# 0                   2                  2                    2
# 1                  31                 54                   34
# 2                 203                372                  226
# 3                 156                234                  162
# 4                1177               1784                 1226

# %%
trump1 = trump_merge_df.groupby("State").count()["trump_murder_mean"]
trump_total_murder_bar = pd.DataFrame(trump1)

regbar = trump_total_murder_bar.plot.bar(legend=False,rot=80)
plt.title("Total Number of Murders by State")
plt.xlabel("State")
plt.ylabel("trump_murder_mean")
# Out:
# Text(0, 0.5, 'trump_murder_mean')

# %%
trump2 = trump_merge_df.groupby("State").count()["trump_firearms_mean"]
trump_total_firearms_bar = pd.DataFrame(trump2)

regbar = trump_total_firearms_bar.plot.bar(legend=False,rot=80)
plt.title("Total Number of firearms by State")
plt.xlabel("State")
plt.ylabel("trump_murder_mean")
# Out:
# Text(0, 0.5, 'trump_murder_mean')
