# %%
# Import Dependencies
import pandas as pd

# %%
# Store filepath in a variable
df = pd.read_excel('HomicideData.xlsx')
print(df)
# Out:
#                        Weapons   2014   2015   2016   2017   2018
# 0                        Total  12278  13780  15318  15195  14123
# 1               Total_firearms   7803   9103  10372  11006  10265
# 2                     Handguns   5342   6176   6762   7051   6603
# 3                       Rifles    235    215    300    390    297
# 4                     Shotguns    238    247    247    264    235
# 5                   Other guns     88    151    172    180    167
# 6          Firearms_not_stated   1900   2314   2891   3121   2963
# 7   Knives/cutting_instruments   1545   1525   1558   1609   1515
# 8                Blunt_objects    431    436    464    472    443
# 9            Personal_weapons     668    647    664    710    672
# 10                      Poison      9      8     12     15      5
# 11                  Explosives      6      1      1      0      4
# 12                        Fire     55     63     78     96     72
# ...

# %%
# trump 2017 data

df1 = pd.read_excel('Trump_2017.xlsx')
print(df1)
# Out:
#                 State  Total_murders  Total_firearms  Handguns  Rifles  \
# 0             Alabama              2               1         0       0
# 1              Alaska             62              37         7       3
# 2             Arizona            404             249       162       8
# 3            Arkansas            250             168        92      11
# 4          California           1830            1274       886      37
# 5            Colorado            218             137        88       7
# 6         Connecticut            102              72        30       0
# 7            Delaware             52              44        20       0
# 8   District_Columbia            116              90        89       0
# 9             Georgia            672             542       490      15
# 10             Hawaii             39               4         1       1
# 11              Idaho             28              13         8       4
# ...
